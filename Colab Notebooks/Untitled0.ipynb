# %%
class person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def myfun(self):
    print("my name is "+self.name)

p1 = person("sahriar", 22)
p2 = person("KingNafis", 23)
p1.myfun()
p2.myfun()
# Out:
# my name is sahriar
# my name is KingNafis
