# %% [markdown]
# Exercise 1.9.1:

# %%
print(7^2)
# Out:
# 5

# %%
import math

roundPi = round(math.pi, 3)
print(roundPi)
# Out:
# 3.142

# %%
print(5%2)
# Out:
# 1

# %% [markdown]
# Exercise 1.9.2:

# %%
print(round(5.5))
# Out:
# 6

# %%
print(round(6.5))
# Out:
# 6

# %% [markdown]
# Excercise 1.9.3:

# %%
print(2+3)
# Out:
# 5

# %%
print(4, 2)
# Out:
# 4 2

# %% [markdown]
# Exercise 1.9.4:

# %%
print(type(765))
print(type(2.718))
print(type("2 pi"))
print(type(abs(-7)))
print(type(abs(-7.0)))
print(type(abs))
print(type(int))
print(type(type))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'builtin_function_or_method'>
# <class 'type'>
# <class 'type'>

# %% [markdown]
# Exercise 1.9.5:

# %%
print("total seconds:", (42*60)+42)
# Out:
# total seconds: 2562

# %%
print("total miles: ", 10/1.61)
# Out:
# total miles:  6.211180124223602

# %%
pace = (10/1.61)/((42*60)+42)
print("average pace: ", pace)
print("pace in seconds/mile: ",pace)
print("pace in minutes/mile: ",(pace/60))
print("pace in hours/mile: ",(pace/3600))
# Out:
# average pace:  0.0024243482139826703
# pace in seconds/mile:  0.0024243482139826703
# pace in minutes/mile:  (4.040580356637784e-05, 3)
# average pace:  0.0024243482139826703
# pace in seconds/mile:  0.0024243482139826703
# pace in minutes/mile:  4.040580356637784e-05
# pace in hours/mile:  6.734300594396306e-07
